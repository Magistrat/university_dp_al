# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/konstantinnistratov/PycharmProjects/university_dp_al/lab_04/titanic.csv', sep=',')

# %%
tt = pd.DataFrame(data)

# %%
tt
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
tt.head(10)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# ...

# %%
tt.tail(10)
# Out:
#      PassengerId  Pclass                                             Name  \
# 408         1300       3                  Riordan, Miss. Johanna Hannah""
# 409         1301       3                        Peacock, Miss. Treasteall
# 410         1302       3                           Naughton, Miss. Hannah
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 413         1305       3                               Spector, Mr. Woolf
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
# 416         1308       3                              Ware, Mr. Frederick
# 417         1309       3                         Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 408  female   NaN      0      0              334915    7.7208   NaN        Q
# ...

# %%
tt[20:10:-1]
# Out:
#     PassengerId  Pclass                                               Name  \
# 20          912       1                             Rothschild, Mr. Martin
# 19          911       3              Assaf Khalil, Mrs. Mariana (Miriam")"
# 18          910       3                       Ilmakangas, Miss. Ida Livija
# 17          909       3                                  Assaf, Mr. Gerios
# 16          908       2                                  Keane, Mr. Daniel
# 15          907       2      del Carlo, Mrs. Sebastiano (Argenia Genovesi)
# 14          906       1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 13          905       2                               Howard, Mr. Benjamin
# 12          904       1      Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# 11          903       1                         Jones, Mr. Charles Cresson
#
#        Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
tt.size
# Out:
# 4598

# %%
tt.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
tt['Age'].mean()
# Out:
# 30.272590361445783

# %%
age_gender = tt.groupby(['Age', 'Sex'])

# %%
age_gender.head()
# Out:
#      PassengerId  Pclass                                             Name  \
# 0            892       3                                 Kelly, Mr. James
# 1            893       3                 Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                        Myles, Mr. Thomas Francis
# 3            895       3                                 Wirz, Mr. Albert
# 4            896       3     Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                              ...
# 409         1301       3                        Peacock, Miss. Treasteall
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
tt.groupby(['Age', 'Sex'])

# %%
tt['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
tt['Sex'].nunique()
# Out:
# 2

# %%
tt['Sex'].value_counts()
# Out:
# Sex
# male      266
# female    152
# Name: count, dtype: int64

# %%
tt['Age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
tt['Age'].plot()
# Out:
# <Axes: >

# %%
tt['Age'].plot.area()
# Out:
# <Axes: >

# %%
tt['Age'].plot.bar()
# Out:
# <Axes: >

# %%
tt['Age'].plot.pie()
# Out:
# <Axes: ylabel='Age'>

# %%
age_sex = tt[['Age', 'Sex']]

# %%
age_sex
# Out:
#       Age     Sex
# 0    34.5    male
# 1    47.0  female
# 2    62.0    male
# 3    27.0    male
# 4    22.0  female
# ..    ...     ...
# 413   NaN    male
# 414  39.0  female
# 415  38.5    male
# 416   NaN    male
# 417   NaN    male
#
# [418 rows x 2 columns]

# %%
age_sex.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
tt
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
tt.iloc[1]
# Out:
# PassengerId                                 893
# Pclass                                        3
# Name           Wilkes, Mrs. James (Ellen Needs)
# Sex                                      female
# Age                                        47.0
# SibSp                                         1
# Parch                                         0
# Ticket                                   363272
# Fare                                        7.0
# Cabin                                       NaN
# Embarked                                      S
# Name: 1, dtype: object

# %%
tt['Age'].max()
# Out:
# 76.0

# %%
tt['Age'].min()
# Out:
# 0.17

# %%
tt['Age'].mean()
# Out:
# 30.272590361445783

# %%
import numpy as np
tt.groupby(['Sex'])['Age'].agg(np.mean)
# Out:
# /var/folders/85/dnffnd211cbffc5jnc11bv5m0000gn/T/ipykernel_19247/2207372.py:2: FutureWarning: The provided callable <function mean at 0x10aa41300> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   tt.groupby(['Sex'])['Age'].agg(np.mean)
# Sex
# female    30.272362
# male      30.272732
# Name: Age, dtype: float64

# %%
gs = tt.groupby(['Sex'])['Age'].agg(np.mean)
# Out:
# /var/folders/85/dnffnd211cbffc5jnc11bv5m0000gn/T/ipykernel_19247/689584165.py:1: FutureWarning: The provided callable <function mean at 0x10aa41300> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   gs = tt.groupby(['Sex'])['Age'].agg(np.mean)

# %%
gs.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
pass_count = tt.groupby(['Sex'])['PassengerId'].count()

# %%
pass_count.plot.pi
